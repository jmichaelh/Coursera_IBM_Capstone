# %% [markdown]
# # **Introduction**
# >*This Analysis of Paris Arrondissements, will include information pulled from the internet, including FourSquare Data to provide travelers, researchers, and other interested parties with neighborhood statistics such as density, population, landmarks, and locations.  Initially created to pull information on the 20 arrondissements of Paris, however data on the four quarters (Quartiers) of each arrondissementseemed to be more relevant and at a more detailed segment for neighborhood exploration at the venue level.

# %% [markdown]
# # **Data Requirements and Descriptions**

# %% [markdown]
# ### **Install and Import Libraries**
#
# >*Setup the initial environment, using pip, it may be necessary to install the below models before importing modules </br>(some may not be needed, depending on prior usage and installations)*
#
# >*For this project, I have choosen the following libraries and modules which will be used throughout the analysis*

# %%
import bs4
import os
import csv
import json
import geopy
import folium
import requests
import geocoder
import descartes
import geopandas
import numpy as np
import pandas as pd
import geopandas as gpd
from geopy import geocoders
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
from geopy.geocoders import Bing
from geopy.geocoders import GoogleV3
from geopy.geocoders import Nominatim
from shapely.geometry import Point, Polygon

# %% [markdown]
# ### 80 Parisian Neighborhoods or *'Quartiers'* within 20 Parisian *'Arrondissements'*.

# %% [markdown]
# >As an initial starting point, we first scrape our list of neighborhoods from data within the website 'https://en.wikipedia.org/wiki/Quarters_of_Paris'.
# >
# >This data will be the beginning of our neighborhood dataset.</br>
# >
# >*Use "requests.get" to grab the html which is then parsed with Pandas and stored in a list.*
# >
# >Once displayed we see 80 rows of data (4 quarters X 20 arrondissements), each with features detailing: </br>
# >**Arrondissement Number** and 'called' **Name, Quarter Number, Quarter Name, Population**, and **Area** in hectares
# >

# %%
url = 'https://en.wikipedia.org/wiki/Quarters_of_Paris'
data = requests.get(url)
df_list = pd.read_html(data.text)

df = df_list[0]
df.head()
# Out:
#                    Arrondissement(Districts) Quartiers(Quarters)  \
# 0     1st arrondissement(Called "du Louvre")                 1st
# 1     1st arrondissement(Called "du Louvre")                 2nd
# 2     1st arrondissement(Called "du Louvre")                 3rd
# 3     1st arrondissement(Called "du Louvre")                 4th
# 4  2nd arrondissement(Called "de la Bourse")                 5th
#
#        Quartiers(Quarters).1  Population in1999[3]  Area(hectares)[3]  Map
# 0  Saint-Germain-l'Auxerrois                  1672               86.9  NaN
# 1                 Les Halles                  8984               41.2  NaN
# 2               Palais-Royal                  3195               27.4  NaN
# 3              Place-Vendôme                  3044               26.9  NaN
# 4                    Gaillon                  1345               18.8  NaN

# %% [markdown]
# >I did not use BeautifulSoup, but it should produce similar results.

# %% [markdown]
# >*Add two columns "Place" and "Arrondissement" in order to hold the split data from the first column "Arrondissement(Districts)"*

# %%
column_names = ['Arrondissements', 'Quartiers_num', 'Quartier', 'Population', 'Area', 'Map', 'Arrond',  'Aname', 'Place', 'Anum',  'Qnum']
df = df.set_axis(['Arrondissements', 'Quartiers_num', 'Quartier', 'Population', 'Area', 'Map'], axis=1, inplace=False)
P_df = pd.DataFrame(df, columns=column_names)

# %%
P_df['Arrond'] = df['Arrondissements'].str.split('Called').str[0]
P_df['Aname'] = P_df['Arrondissements'].str.split('Called').str[1]
P_df['Aname'] = P_df['Aname'].str.split('"').str[1]
P_df['Arrond'] = P_df['Arrondissements'].str.split('(').str[0]
P_df['Place'] = P_df['Arrondissements'].str.split('"').str[1]
P_df['Anum'] = P_df['Arrond'].str.split("s").str[0]
P_df['Anum'] = P_df['Anum'].str.split('n').str[0]
P_df['Anum'] = P_df['Anum'].str.split('t').str[0]
P_df['Anum'] = P_df['Anum'].str.split('r').str[0]
P_df['Qnum'] = P_df['Quartiers_num'].str.split('s').str[0]
P_df['Qnum'] = P_df['Qnum'].str.split('n').str[0]
P_df['Qnum'] = P_df['Qnum'].str.split('r').str[0]
P_df['Qnum'] = P_df['Qnum'].str.split('t').str[0]

# %%
P_df
# Out:
#                                       Arrondissements Quartiers_num  \
# 0              1st arrondissement(Called "du Louvre")           1st
# 1              1st arrondissement(Called "du Louvre")           2nd
# 2              1st arrondissement(Called "du Louvre")           3rd
# 3              1st arrondissement(Called "du Louvre")           4th
# 4           2nd arrondissement(Called "de la Bourse")           5th
# 5           2nd arrondissement(Called "de la Bourse")           6th
# 6           2nd arrondissement(Called "de la Bourse")           7th
# 7           2nd arrondissement(Called "de la Bourse")           8th
# 8              3rd arrondissement(Called "du Temple")           9th
# 9              3rd arrondissement(Called "du Temple")          10th
# 10             3rd arrondissement(Called "du Temple")          11th
# 11             3rd arrondissement(Called "du Temple")          12th
# 12   4th arrondissement(Called "de l'Hôtel-de-Ville")          13th
# 13   4th arrondissement(Called "de l'Hôtel-de-Ville")          14th
# 14   4th arrondissement(Called "de l'Hôtel-de-Ville")          15th
# 15   4th arrondissement(Called "de l'Hôtel-de-Ville")          16th
# 16           5th arrondissement(Called "du Panthéon")          17th
# 17           5th arrondissement(Called "du Panthéon")          18th
# 18           5th arrondissement(Called "du Panthéon")          19th
# 19           5th arrondissement(Called "du Panthéon")          20th
# 20         6th arrondissement(Called "du Luxembourg")          21st
# 21         6th arrondissement(Called "du Luxembourg")          22nd
# 22         6th arrondissement(Called "du Luxembourg")          23rd
# 23         6th arrondissement(Called "du Luxembourg")          24th
# 24     7th arrondissement(Called "du Palais-Bourbon")          25th
# 25     7th arrondissement(Called "du Palais-Bourbon")          26th
# 26     7th arrondissement(Called "du Palais-Bourbon")          27th
# 27     7th arrondissement(Called "du Palais-Bourbon")          28th
# 28           8th arrondissement(Called "de l'Élysée")          29th
# 29           8th arrondissement(Called "de l'Élysée")          30th
# ..                                                ...           ...
# 50         13th arrondissement(Called "des Gobelins")          51st
# 51         13th arrondissement(Called "des Gobelins")          52nd
# 52    14th arrondissement(Called "de l'Observatoire")          53rd
# 53    14th arrondissement(Called "de l'Observatoire")          54th
# 54    14th arrondissement(Called "de l'Observatoire")          55th
# 55    14th arrondissement(Called "de l'Observatoire")          56th
# 56         15th arrondissement(Called "de Vaugirard")          57th
# 57         15th arrondissement(Called "de Vaugirard")          58th
# 58         15th arrondissement(Called "de Vaugirard")          59th
# 59         15th arrondissement(Called "de Vaugirard")          60th
# 60             16th arrondissement(Called "de Passy")          61st
# 61             16th arrondissement(Called "de Passy")          62nd
# 62             16th arrondissement(Called "de Passy")          63rd
# 63             16th arrondissement(Called "de Passy")          64th
# 64  17th arrondissement(Called "des Batignolles-Mo...          65th
# 65  17th arrondissement(Called "des Batignolles-Mo...          66th
# 66  17th arrondissement(Called "des Batignolles-Mo...          67th
# 67  17th arrondissement(Called "des Batignolles-Mo...          68th
# 68  18th arrondissement(Called "des Buttes-Montmar...          69th
# 69  18th arrondissement(Called "des Buttes-Montmar...          70th
# 70  18th arrondissement(Called "des Buttes-Montmar...          71st
# 71  18th arrondissement(Called "des Buttes-Montmar...          72nd
# 72  19th arrondissement(Called "des Buttes-Chaumont")          73rd
# 73  19th arrondissement(Called "des Buttes-Chaumont")          74th
# 74  19th arrondissement(Called "des Buttes-Chaumont")          75th
# 75  19th arrondissement(Called "des Buttes-Chaumont")          76th
# 76      20th arrondissement(Called "de Ménilmontant")          77th
# 77      20th arrondissement(Called "de Ménilmontant")          78th
# 78      20th arrondissement(Called "de Ménilmontant")          79th
# 79      20th arrondissement(Called "de Ménilmontant")          80th
#
#                      Quartier  Population    Area  Map               Arrond  \
# 0   Saint-Germain-l'Auxerrois        1672    86.9  NaN   1st arrondissement
# 1                  Les Halles        8984    41.2  NaN   1st arrondissement
# 2                Palais-Royal        3195    27.4  NaN   1st arrondissement
# 3               Place-Vendôme        3044    26.9  NaN   1st arrondissement
# 4                     Gaillon        1345    18.8  NaN   2nd arrondissement
# 5                    Vivienne        2917    24.4  NaN   2nd arrondissement
# 6                        Mail        5783    27.8  NaN   2nd arrondissement
# 7              Bonne-Nouvelle        9595    28.2  NaN   2nd arrondissement
# 8             Arts-et-Métiers        9560    31.8  NaN   3rd arrondissement
# 9              Enfants-Rouges        8562    27.2  NaN   3rd arrondissement
# 10                   Archives        8609    36.8  NaN   3rd arrondissement
# 11               Sainte-Avoye        7501    21.3  NaN   3rd arrondissement
# 12                Saint-Merri        6523    31.3  NaN   4th arrondissement
# 13              Saint-Gervais       10587    42.2  NaN   4th arrondissement
# 14                    Arsenal        9474    48.7  NaN   4th arrondissement
# 15                 Notre-Dame        4087    37.9  NaN   4th arrondissement
# 16      Quartier Saint-Victor       11661    60.4  NaN   5th arrondissement
# 17         Jardin-des-Plantes       18005    79.8  NaN   5th arrondissement
# 18               Val-de-Grâce       19492    70.4  NaN   5th arrondissement
# 19                   Sorbonne        9683    43.3  NaN   5th arrondissement
# 20                    Monnaie        6185    29.3  NaN   6th arrondissement
# 21                      Odéon        8833    71.6  NaN   6th arrondissement
# 22      Notre-Dame-des-Champs       24731    86.1  NaN   6th arrondissement
# 23     Saint-Germain-des-Prés        5154    28.2  NaN   6th arrondissement
# 24       Saint-Thomas-d'Aquin       12661    82.7  NaN   7th arrondissement
# 25              Les Invalides        6276   107.4  NaN   7th arrondissement
# 26            École-Militaire       12895    80.8  NaN   7th arrondissement
# 27               Gros-Caillou       25156   138.2  NaN   7th arrondissement
# 28             Champs-Élysées        4614   114.1  NaN   8th arrondissement
# 29          Faubourg-du-Roule       10038    79.6  NaN   8th arrondissement
# ..                        ...         ...     ...  ...                  ...
# 50             Maison-Blanche       64797   223.2  NaN  13th arrondissement
# 25        du Palais-Bourbon        du Palais-Bourbon    7   26
# 26        du Palais-Bourbon        du Palais-Bourbon    7   27
# 27        du Palais-Bourbon        du Palais-Bourbon    7   28
# 28              de l'Élysée              de l'Élysée    8   29
# 29              de l'Élysée              de l'Élysée    8   30
# ..                      ...                      ...  ...  ...
# 50             des Gobelins             des Gobelins   13   51
# 51             des Gobelins             des Gobelins   13   52
# 52        de l'Observatoire        de l'Observatoire   14   53
# 53        de l'Observatoire        de l'Observatoire   14   54
# 54        de l'Observatoire        de l'Observatoire   14   55
# 55        de l'Observatoire        de l'Observatoire   14   56
# 56             de Vaugirard             de Vaugirard   15   57
# 57             de Vaugirard             de Vaugirard   15   58
# 58             de Vaugirard             de Vaugirard   15   59
# 59             de Vaugirard             de Vaugirard   15   60
# 60                 de Passy                 de Passy   16   61
# 61                 de Passy                 de Passy   16   62
# 62                 de Passy                 de Passy   16   63
# 63                 de Passy                 de Passy   16   64
# 64  des Batignolles-Monceau  des Batignolles-Monceau   17   65
# 65  des Batignolles-Monceau  des Batignolles-Monceau   17   66
# 66  des Batignolles-Monceau  des Batignolles-Monceau   17   67
# 67  des Batignolles-Monceau  des Batignolles-Monceau   17   68
# 68    des Buttes-Montmartre    des Buttes-Montmartre   18   69
# 69    des Buttes-Montmartre    des Buttes-Montmartre   18   70
# 70    des Buttes-Montmartre    des Buttes-Montmartre   18   71
# 71    des Buttes-Montmartre    des Buttes-Montmartre   18   72
# 72      des Buttes-Chaumont      des Buttes-Chaumont   19   73
# 73      des Buttes-Chaumont      des Buttes-Chaumont   19   74
# 74      des Buttes-Chaumont      des Buttes-Chaumont   19   75
# 75      des Buttes-Chaumont      des Buttes-Chaumont   19   76
# 76          de Ménilmontant          de Ménilmontant   20   77
# 77          de Ménilmontant          de Ménilmontant   20   78
# 78          de Ménilmontant          de Ménilmontant   20   79
# 79          de Ménilmontant          de Ménilmontant   20   80
#
# [80 rows x 11 columns]

# %% [markdown]
# >*Needing to generate an address for each Quartier in order to pull the geo-coordinates into our data so that data can be pulled from FourSquare to provide end users with the venue specific and street level information that they need*

# %% [markdown]
# #### **Generate the Postal Codes for each Arrondissement**
# Postal codes are given for each arrondissement within Paris where the numbers 751 proceed the number of the arrondissement, for example the 10th Arrondissement of Canal St. Martin woould have a postal zip of 75110.

# %% [markdown]
# >*The Postal Code of the Arrondissements follow the simple formula: Postcode = {75100 + "arrondissement number"}*

# %%
post = pd.DataFrame(columns=['Post', 'Quartiers', 'Postcode'])
post['Qnum'] = df.index.astype(float) + df.index 
post['Post'] = 75100 
post['Postcode'] = post['Post'].astype(float) + P_df['Anum'].astype(float)

# %% [markdown]
# >The data frame on the individual Quartiers is created with the following elements:
#
#     Qrts (Quartiers Number)
#     Quartier
#     Pop (Population)
#     Density (Population / Area)
#     Latitude
#     Longitude
#     Postcode
#     Arrnum (Arrondissement Number)
#     Arrondissement
#     City
#     Country

# %%
arronds = pd.DataFrame(P_df, columns=['Quartier', 'Qrts', 'Anum', 'Arrondissement', 'City', 'Country', 'Postcode', 'Pop', 'Density', 'Latitude', 'Longitude'])
arronds['Arrondissement'] = P_df['Arrondissements']
arronds['Quartier'] = P_df['Quartier']
arronds['Qrts'] = P_df['Quartiers_num']
arronds['City'] = 'Paris'
arronds['Country'] = 'FR'
arronds['Pop'] = P_df['Population']
arronds.reset_index(drop=False, inplace=False)
arronds.head()
# Out:
#                     Quartier Qrts Anum  \
# 0  Saint-Germain-l'Auxerrois  1st    1
# 1                 Les Halles  2nd    1
# 2               Palais-Royal  3rd    1
# 3              Place-Vendôme  4th    1
# 4                    Gaillon  5th    2
#
#                               Arrondissement   City Country  Postcode   Pop  \
# 0     1st arrondissement(Called "du Louvre")  Paris      FR       NaN  1672
# 1     1st arrondissement(Called "du Louvre")  Paris      FR       NaN  8984
# 2     1st arrondissement(Called "du Louvre")  Paris      FR       NaN  3195
# 3     1st arrondissement(Called "du Louvre")  Paris      FR       NaN  3044
# 4  2nd arrondissement(Called "de la Bourse")  Paris      FR       NaN  1345
#
#    Density  Latitude  Longitude
# 0      NaN       NaN        NaN
# 1      NaN       NaN        NaN
# 2      NaN       NaN        NaN
# 3      NaN       NaN        NaN
# 4      NaN       NaN        NaN

# %%
arronds['Density']  = arronds['Pop'].astype(float) / P_df['Area'].astype(float)
arronds['Postcode'] = post['Postcode'].astype(str)
arronds['Postcode'] = arronds['Postcode'].str[:5]

# %% [markdown]
# >*addy DataFrame is created to house the address and location information*

# %%
column_names = ['Qrts', 'Qnum', 'Quartier', 'addressline1', 'addressline', 'town', 'IsoCode', 'Lat', 'Long', 'Error', 'formatted_address', 'location_type']
df_addy = pd.DataFrame(arronds.Quartier,  columns=column_names)
df_addy['Quartier'] = arronds['Quartier'].map(str)
df_addy['Qrts'] = arronds['Qrts']
df_addy['addressline1'] = arronds['Arrondissement'].map(str)
df_addy['town'] = arronds['City'].map(str) 
df_addy['state'] = arronds['Country'].map(str)
df_addy['IsoCode'] = arronds['Postcode']
def removeNonAscii(addy): return "".join(i for i in addy if ord(i)<126 and ord(i)>31)
df_addy['addressline'] = df_addy['addressline1'].str.split('Called').str[0]
df_addy['addressline'] = df_addy['addressline1'].str.split('(').str[0]
df_addy['Add'] = df_addy['Quartier'] + ', ' + df_addy['Qrts'] + ' Quartier' + ',  ' +  df_addy['addressline'] + ', ' + ' Paris, FR  ' + df_addy['IsoCode']
df_addy.to_csv('addresses.csv')

# %%
df_addy['coordinates'] = df_addy['Quartier'] + ' Paris, FR'

# %%
add = df_addy['coordinates']
addy = pd.DataFrame(df_addy, columns = ['Qnum', 'Qrts', 'Quartier', 'addressline', 'IsoCode', 'Add', 'coordinates'])
addy['Qnum'] = P_df['Qnum']
addy['Qrts'] = df_addy['Qrts']
addy['Quartier'] = df_addy['Quartier']
addy['coordinates'] = add

# %% [markdown]
# >*Use the geocoder to pull the longitude and latitude*

# %%
location= [x for x in addy['coordinates'].unique().tolist() 
            if type(x) == str]

latitude = []
longitude =  []
qrts = []

for i in range(0, len(location)):
    try:
        address = location[i]
        qrts = addy.Qrts[i]
        geolocator = Nominatim(user_agent="paris_explorer")
        loc = geolocator.geocode(address)
        latitude.append(loc.latitude)
        longitude.append(loc.longitude)
        print('Geo Coordinates: {}, {}, {}.'.format(loc.latitude, loc.longitude, qrts))
    except:
        latitude.append(np.nan)
        longitude.append(np.nan)

df_ = pd.DataFrame({'location':location, 
                    'location_qrts':qrts,
                    'location_latitude': latitude,
                    'location_longitude':longitude,
                    })
# Out:
# Geo Coordinates: 48.860211199999995, 2.3362988847682233, 1st.
# Geo Coordinates: 48.8621801, 2.3458118, 2nd.
# Geo Coordinates: 48.863584700000004, 2.3362042200938715, 3rd.
# Geo Coordinates: 48.867463400000005, 2.329428116825194, 4th.
# Geo Coordinates: 48.869135150000005, 2.332908770335507, 5th.
# Geo Coordinates: 48.86885895, 2.3393625582679, 6th.
# Geo Coordinates: 48.8680539, 2.344592949731121, 7th.
# Geo Coordinates: 48.8706233, 2.3487498, 8th.
# Geo Coordinates: 48.8654414, 2.3561316, 9th.
# Geo Coordinates: 48.864240949999996, 2.3625854822185506, 10th.
# Geo Coordinates: 48.859571349999996, 2.3625762007242033, 11th.
# Geo Coordinates: 48.862699750000004, 2.354135471358302, 12th.
# Geo Coordinates: 48.85845555, 2.3517023379560156, 13th.
# Geo Coordinates: 48.8555813, 2.3583593578227955, 14th.
# Geo Coordinates: 48.85157155, 2.364795174126021, 15th.
# Geo Coordinates: 48.85293705, 2.3500501225000026, 16th.
# Geo Coordinates: 48.84792605, 2.355269043333334, 17th.
# Geo Coordinates: 48.8432224, 2.3595089570948424, 18th.
# Geo Coordinates: 48.84221255, 2.343882249183209, 19th.
# Geo Coordinates: 48.84912335, 2.3453251499821075, 20th.
# Geo Coordinates: 48.85458085, 2.3401503125043908, 21st.
# Geo Coordinates: 48.8522428, 2.3393369, 22nd.
# Geo Coordinates: 48.844688, 2.3288305, 23rd.
# Geo Coordinates: 48.8544286, 2.3337071, 24th.
# Geo Coordinates: 48.85492565, 2.3253111208231116, 25th.
# Geo Coordinates: 48.8570374, 2.3118779, 26th.
# Geo Coordinates: 48.851848399999994, 2.304756478078534, 27th.
# Geo Coordinates: 48.857394299999996, 2.3005401034756554, 28th.
# Geo Coordinates: 48.8707573, 2.3053312, 29th.
# Geo Coordinates: 48.8777215, 2.2983559, 30th.
# Geo Coordinates: 48.870137299999996, 2.324562486939328, 31st.
# Geo Coordinates: 48.8787676, 2.3222643, 32nd.
# Geo Coordinates: 48.8784469, 2.337458, 33rd.
# Geo Coordinates: 48.873198450000004, 2.332258871790902, 34th.
# Geo Coordinates: 48.873702949999995, 2.342911681495643, 35th.
# Geo Coordinates: 48.88011775, 2.3450036716652027, 36th.
# Geo Coordinates: 48.88006515, 2.356771823320905, 37th.
# Geo Coordinates: 48.8697934, 2.352686299285678, 38th.
# Geo Coordinates: 48.86914585, 2.355651470716479, 39th.
# Geo Coordinates: 48.876607500000006, 2.3663683466669045, 40th.
# Geo Coordinates: 48.867379549999995, 2.3734230412220754, 41st.
# Geo Coordinates: 48.8610516, 2.3747956, 42nd.
# Geo Coordinates: 48.8572797, 2.381206126697574, 43rd.
# Geo Coordinates: 48.852403800000005, 2.385894958919927, 44th.
# Geo Coordinates: 48.8413382, 2.4009317, 45th.
# Geo Coordinates: 48.8450751, 2.40108, 46th.
# Geo Coordinates: 48.8367988, 2.380847, 47th.
# Geo Coordinates: 48.84677005, 2.3746097217407476, 48th.
# Geo Coordinates: 48.8378168, 2.3646808393179137, 49th.
# Geo Coordinates: 48.82789775, 2.3728769052567555, 50th.
# Geo Coordinates: 48.8224745, 2.358504, 51st.
# Geo Coordinates: 48.833974, 2.347634171992322, 52nd.
# Geo Coordinates: 48.8434755, 2.3282995, 53rd.
# Geo Coordinates: 48.8219907, 2.337792153286488, 54th.
# Geo Coordinates: 48.826937900000004, 2.326241053514776, 55th.
# Geo Coordinates: 48.8317799, 2.3140252, 56th.
# Geo Coordinates: 48.8344438, 2.298215644730872, 57th.
# Geo Coordinates: 48.8419775, 2.31291379144126, 58th.
# Geo Coordinates: 48.8538898, 2.2893811, 59th.
# Geo Coordinates: 48.83924675, 2.279049917924877, 60th.
# Geo Coordinates: 48.8477221, 2.2667376, 61st.
# Geo Coordinates: 48.8579754, 2.274062, 62nd.
# Geo Coordinates: 48.871318, 2.2777713, 63rd.
# Geo Coordinates: 48.868918449999995, 2.2921131852552343, 64th.
# Geo Coordinates: 48.8807219, 2.2944263, 65th.
# Geo Coordinates: 48.88572895, 2.300543431768688, 66th.
# Geo Coordinates: 48.8863552, 2.321457, 67th.
# Geo Coordinates: 48.8937508, 2.319855827428138, 68th.
# Geo Coordinates: 48.89212585, 2.3335235220672503, 69th.
# Geo Coordinates: 48.8940584, 2.345678, 70th.
# Geo Coordinates: 48.89267625, 2.3560402076071743, 71st.
# Geo Coordinates: 48.8844068, 2.3603057, 72nd.
# Geo Coordinates: 48.8904889, 2.3800721, 73rd.
# Geo Coordinates: 48.8947282, 2.3823046, 74th.
# Geo Coordinates: 48.8824235, 2.3940248685898715, 75th.
# Geo Coordinates: 48.8774215, 2.3710197, 76th.
# Geo Coordinates: 48.8717265, 2.385085, 77th.
# Geo Coordinates: 48.8703623, 2.4067355726428277, 78th.
# Geo Coordinates: 48.8612168, 2.3939292638106417, 79th.
# Geo Coordinates: 48.8547441, 2.3853565, 80th.

# %% [markdown]
# # **Methodology**
#
# >Venue Availability and Popularity
# >>*Utilizing the Foursquare API to pull data on establishments in various Paris neighborhoods, comparing both to each other and to the population to show availabiltiy and popularity of types of establishments in certain areas.*

# %%
addy['Lat'] = df_['location_latitude']
addy['Lon'] = df_['location_longitude']

# %% [markdown]
# >*data is pulled together into the DataFrame. "parcoord", for a more concise output*

# %%
parcoord = pd.DataFrame(arronds[['Quartier','Latitude', 'Longitude', 'Postcode']])
parcoord['Qrts'] = addy['Qrts']
parcoord['c_qu'] = addy['Qnum']
parcoord['num_arrond'] = arronds['Anum'].astype(str) +  'e'
parcoord['Quartier'] = arronds['Quartier']
parcoord['Postcode'] = addy['IsoCode']
parcoord['Address'] = addy['Add']
parcoord['Latitude'] = addy['Lat']
parcoord['Longitude'] = addy['Lon']
parcoord['Landmark'] = addy['Quartier']
parcoord['Density'] = arronds['Density']
parcoord['Population'] = arronds['Pop']
parcoord.head()
# Out:
#                     Quartier   Latitude  Longitude Postcode Qrts c_qu  \
# 0  Saint-Germain-l'Auxerrois  48.860211   2.336299    75101  1st    1
# 1                 Les Halles  48.862180   2.345812    75101  2nd    2
# 2               Palais-Royal  48.863585   2.336204    75101  3rd    3
# 3              Place-Vendôme  48.867463   2.329428    75101  4th    4
# 4                    Gaillon  48.869135   2.332909    75102  5th    5
#
#   num_arrond                                            Address  \
# 0         1e  Saint-Germain-l'Auxerrois, 1st Quartier,  1st ...
# 1         1e  Les Halles, 2nd Quartier,  1st arrondissement,...
# 2         1e  Palais-Royal, 3rd Quartier,  1st arrondissemen...
# 3         1e  Place-Vendôme, 4th Quartier,  1st arrondisseme...
# 4         2e  Gaillon, 5th Quartier,  2nd arrondissement,  P...
#
#                     Landmark     Density  Population
# 0  Saint-Germain-l'Auxerrois   19.240506        1672
# 1                 Les Halles  218.058252        8984
# 2               Palais-Royal  116.605839        3195
# 3              Place-Vendôme  113.159851        3044
# 4                    Gaillon   71.542553        1345

# %% [markdown]
# >*In  order to establish the Paris area being analyzed, and plot the boundaries of our density areas, a map shapefile is downloaded to our repository and opened.   An appropriate file showing the administrative zones of Arrondissements and Quartiers in Paris is found thorugh the geo-file libraries at Stanford University.  Our later pulled FourSquare venue data based on our coordinatess pulled in by .

# %%
import geopandas as gdp
fname = 'quartier_paris.geojson'
geo_data = gpd.read_file(fname)
geo_data.head(3)
# Out:
#      n_sq_qu    n_sq_ar  c_qu       surface                 l_qu    perimetre  \
# 0  750000026  750000007    26  1.073734e+06            Invalides  4434.656489
# 1  750000035  750000009    35  4.173351e+05  Faubourg-Montmartre  2786.541926
# 2  750000005  750000002     5  1.880122e+05              Gaillon  1866.982041
#
#    c_quinsee  c_ar                                           geometry
# 0    7510702     7  POLYGON ((2.31901 48.85174, 2.31903 48.85170, ...
# 1    7510903     9  POLYGON ((2.34026 48.87660, 2.34228 48.87651, ...
# 2    7510201     2  POLYGON ((2.33632 48.86797, 2.33587 48.86700, ...

# %% [markdown]
# >*Only the "c_qu" and "geometry" columns are needed from our json shapefile to create the base and boundaries of the map*

# %%
geo_data = geo_data.sort_values(by=['c_qu'])
geo_data = geo_data[['c_qu', 'geometry']]
geo_data.head(3)
# Out:
#     c_qu                                           geometry
# 7      1  POLYGON ((2.34459 48.85405, 2.34459 48.85405, ...
# 30     2  POLYGON ((2.34937 48.86058, 2.34822 48.85852, ...
# 23     3  POLYGON ((2.33947 48.86214, 2.33912 48.86148, ...

# %% [markdown]
# >*From the former parcoord DataFrame,  we can merge information for our  map, including the already calculated Density (Population per hectare) figure and the Population*

# %%
parcoord.head(1)
# Out:
#                     Quartier   Latitude  Longitude Postcode Qrts c_qu  \
# 0  Saint-Germain-l'Auxerrois  48.860211   2.336299    75101  1st    1
#
#   num_arrond                                            Address  \
# 0         1e  Saint-Germain-l'Auxerrois, 1st Quartier,  1st ...
#
#                     Landmark    Density  Population
# 0  Saint-Germain-l'Auxerrois  19.240506        1672

# %%
column_names = ['c_qu', 'num_arrond', 'Quartier', 'Density', 'Population', 'Longitude', 'Latitude']
dens = pd.DataFrame(parcoord, columns = column_names)                 
dens.head(3)
# Out:
#   c_qu num_arrond                   Quartier     Density  Population  \
# 0    1         1e  Saint-Germain-l'Auxerrois   19.240506        1672
# 1    2         1e                 Les Halles  218.058252        8984
# 2    3         1e               Palais-Royal  116.605839        3195
#
#    Longitude   Latitude
# 0   2.336299  48.860211
# 1   2.345812  48.862180
# 2   2.336204  48.863585

# %% [markdown]
# >*all map plotting data is pulled toogether in "paris_plotting"*

# %%
geo_data['c_qu'] = geo_data.c_qu.astype(int)
dens['c_qu'] = dens.c_qu.astype(int)
paris_plotting = pd.DataFrame(geo_data)
paris_plotting = geo_data.merge(dens, on = 'c_qu')
paris_plotting.head(2)
# Out:
#    c_qu                                           geometry num_arrond  \
# 0     1  POLYGON ((2.34459 48.85405, 2.34459 48.85405, ...         1e
# 1     2  POLYGON ((2.34937 48.86058, 2.34822 48.85852, ...         1e
#
#                     Quartier     Density  Population  Longitude   Latitude
# 0  Saint-Germain-l'Auxerrois   19.240506        1672   2.336299  48.860211
# 1                 Les Halles  218.058252        8984   2.345812  48.862180

# %% [markdown]
# Normalize the density data to values between 0 and 1

# %% [markdown]
# >*Density and Population data was normalized*

# %%
dens['Dens_norm'] = (dens['Density'] - min(dens.Density)) / (max(dens.Density)-min(dens.Density))
paris_plotting['Dens_norm'] = dens['Dens_norm']

dens['Pop_norm'] = (dens['Population'] - min(dens['Population'])) / (max(dens['Population'])-min(dens['Population']))
paris_plotting['Pop_norm'] = dens['Pop_norm']

dens = dens.sort_values(by=['Dens_norm'])
dens['c_qu'] = dens['c_qu'].astype(int)  
dens.head(3)
# Out:
#     c_qu num_arrond                   Quartier    Density  Population  \
# 52    53        14e               Montparnasse  16.492007       18570
# 0      1         1e  Saint-Germain-l'Auxerrois  19.240506        1672
# 28    29         8e             Champs-Élysées  40.438212        4614
#
#     Longitude   Latitude  Dens_norm  Pop_norm
# 52   2.328299  48.843475   0.000000  0.213479
# 0    2.336299  48.860211   0.006274  0.004053
# 28   2.305331  48.870757   0.054662  0.040515

# %% [markdown]
# >*'paris_plot' is created to combine the population information and the geospacial data*

# %%
paris_plot = pd.DataFrame(paris_plotting, columns = ['c_qu', 'geometry', 'Quartier', 'Density', 'Dens_norm', 'Pop_norm', 'Population'])
paris_plot = paris_plot.sort_values(by=['Dens_norm'])
paris_plot.tail(3)
# Out:
#     c_qu                                           geometry         Quartier  \
# 76    77  POLYGON ((2.38323 48.86710, 2.38314 48.86708, ...       Belleville
# 35    36  POLYGON ((2.34971 48.88222, 2.34983 48.88109, ...     Rochechouart
# 40    41  POLYGON ((2.37010 48.86376, 2.36690 48.86246, ...  Folie-Méricourt
#
#        Density  Dens_norm  Pop_norm  Population
# 76  443.283767   0.974230  0.426686       35773
# 35  443.353293   0.974389  0.258617       22212
# 40  454.573003   1.000000  0.392343       33002

# %%
paris_plot.to_csv('paris_plot.csv')

# %% [markdown]
# >*Creating a colormap in atttempt to show density levels on a map*

# %% [markdown]
# >This will be used to give us a range of color codes one for each quartiers weight in population

# %%
from branca.colormap import linear

colormap = linear.GnBu_09.scale(
    paris_plot.Dens_norm.min(),
    paris_plot.Dens_norm.max())

print(colormap(1.0))

colormap
# Out:
# #084081ff
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#f7fcf0ff;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#f7fcf0ff;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#f7fcf0ff;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#f6fcefff;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#f6fcefff;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#f6fcefff;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#f5fceeff;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#f5fbeeff;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#f5fbeeff;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#f4fbedff;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#f4fbedff;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#f3fbedff;stroke-width:3;" /><line x1="12" y1="0" x2="12" y2="20" style="stroke:#f3fbecff;stroke-width:3;" /><line x1="13" y1="0" x2="13" y2="20" style="stroke:#f3fbecff;stroke-width:3;" /><line x1="14" y1="0" x2="14" y2="20" style="stroke:#f2faecff;stroke-width:3;" /><line x1="15" y1="0" x2="15" y2="20" style="stroke:#f2faebff;stroke-width:3;" /><line x1="16" y1="0" x2="16" y2="20" style="stroke:#f2faebff;stroke-width:3;" /><line x1="17" y1="0" x2="17" y2="20" style="stroke:#f1faebff;stroke-width:3;" /><line x1="18" y1="0" x2="18" y2="20" style="stroke:#f1faeaff;stroke-width:3;" /><line x1="19" y1="0" x2="19" y2="20" style="stroke:#f0faeaff;stroke-width:3;" /><line x1="20" y1="0" x2="20" y2="20" style="stroke:#f0faeaff;stroke-width:3;" /><line x1="21" y1="0" x2="21" y2="20" style="stroke:#f0f9e9ff;stroke-width:3;" /><line x1="22" y1="0" x2="22" y2="20" style="stroke:#eff9e9ff;stroke-width:3;" /><line x1="23" y1="0" x2="23" y2="20" style="stroke:#eff9e9ff;stroke-width:3;" /><line x1="24" y1="0" x2="24" y2="20" style="stroke:#eff9e8ff;stroke-width:3;" /><line x1="25" y1="0" x2="25" y2="20" style="stroke:#eef9e8ff;stroke-width:3;" /><line x1="26" y1="0" x2="26" y2="20" style="stroke:#eef9e8ff;stroke-width:3;" /><line x1="27" y1="0" x2="27" y2="20" style="stroke:#edf9e7ff;stroke-width:3;" /><line x1="28" y1="0" x2="28" y2="20" style="stroke:#edf8e7ff;stroke-width:3;" /><line x1="29" y1="0" x2="29" y2="20" style="stroke:#edf8e7ff;stroke-width:3;" /><line x1="30" y1="0" x2="30" y2="20" style="stroke:#ecf8e6ff;stroke-width:3;" /><line x1="31" y1="0" x2="31" y2="20" style="stroke:#ecf8e6ff;stroke-width:3;" /><line x1="32" y1="0" x2="32" y2="20" style="stroke:#ecf8e6ff;stroke-width:3;" /><line x1="33" y1="0" x2="33" y2="20" style="stroke:#ebf8e5ff;stroke-width:3;" /><line x1="34" y1="0" x2="34" y2="20" style="stroke:#ebf8e5ff;stroke-width:3;" /><line x1="35" y1="0" x2="35" y2="20" style="stroke:#ebf7e5ff;stroke-width:3;" /><line x1="36" y1="0" x2="36" y2="20" style="stroke:#eaf7e4ff;stroke-width:3;" /><line x1="37" y1="0" x2="37" y2="20" style="stroke:#eaf7e4ff;stroke-width:3;" /><line x1="38" y1="0" x2="38" y2="20" style="stroke:#e9f7e4ff;stroke-width:3;" /><line x1="39" y1="0" x2="39" y2="20" style="stroke:#e9f7e3ff;stroke-width:3;" /><line x1="40" y1="0" x2="40" y2="20" style="stroke:#e9f7e3ff;stroke-width:3;" /><line x1="41" y1="0" x2="41" y2="20" style="stroke:#e8f7e3ff;stroke-width:3;" /><line x1="42" y1="0" x2="42" y2="20" style="stroke:#e8f6e2ff;stroke-width:3;" /><line x1="43" y1="0" x2="43" y2="20" style="stroke:#e8f6e2ff;stroke-width:3;" /><line x1="44" y1="0" x2="44" y2="20" style="stroke:#e7f6e2ff;stroke-width:3;" /><line x1="45" y1="0" x2="45" y2="20" style="stroke:#e7f6e1ff;stroke-width:3;" /><line x1="46" y1="0" x2="46" y2="20" style="stroke:#e6f6e1ff;stroke-width:3;" /><line x1="47" y1="0" x2="47" y2="20" style="stroke:#e6f6e1ff;stroke-width:3;" /><line x1="48" y1="0" x2="48" y2="20" style="stroke:#e6f6e0ff;stroke-width:3;" /><line x1="49" y1="0" x2="49" y2="20" style="stroke:#e5f5e0ff;stroke-wid ...

# %%
paris_plotcolor = paris_plot.set_index('c_qu')['Dens_norm']
paris_plotcolor[8]
color_dict = {key: colormap(paris_plotcolor[key]) for key in paris_plotcolor.keys()}
colorscale = pd.DataFrame.from_dict(color_dict, orient='index', columns=['colorscale'])
ppc = paris_plot.merge(colorscale, left_on=None, right_on=None, left_index=True,  right_index=True)
ppc = ppc.sort_values(by=['Dens_norm'])
ppc.head(1)
# Out:
#     c_qu                                           geometry      Quartier  \
# 52    53  POLYGON ((2.34159 48.83481, 2.34127 48.83312, ...  Montparnasse
#
#       Density  Dens_norm  Pop_norm  Population colorscale
# 52  16.492007        0.0  0.213479       18570  #55b7d1ff

# %% [markdown]
# >*Generating the map center point, this will be used for the basemap below (pmap)*

# %%
x_map=paris_plotting.Latitude[1]
y_map=paris_plotting.Longitude[2]
print(x_map,y_map)
# Out:
# 48.8621801 2.3362042200938715

# %%
pmap = folium.Map(location=[x_map, y_map], zoom_start=12,tiles='OpenStreetMap')
pmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# >*the geo_data file is pulled from a downloaded geojson file containing the boundaries for the Paris quartiers*

# %%
geo_data=geopandas.read_file('quartier_paris.geojson')
with open('quartier_paris.geojson') as f:
    paris_dict = json.load(f)
    
geo_data=gpd.GeoDataFrame(geo_data)
geo_data['Population'] = round(ppc['Population'],2)
geo_data['Density'] = round(ppc['Density'],2)
geo_data = gpd.GeoDataFrame(geo_data , geometry = geo_data.geometry)
geo_data.crs={'init':'EPSG:4326'}
geo_data = geo_data.sort_values(by=['Density'])
geo_data['perimetre'] = round(geo_data['perimetre'], 0)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
# 37  POLYGON ((2.24562 48.87636, 2.25482 48.87408, ...     15066.0   319.19
# 55  POLYGON ((2.36456 48.84366, 2.36450 48.84358, ...     57229.0   320.61
# 58  POLYGON ((2.41125 48.82966, 2.41195 48.82934, ...     47411.0   320.78
# 67  POLYGON ((2.39536 48.85670, 2.39444 48.85657, ...     44352.0   321.86
# 45  POLYGON ((2.34967 48.88374, 2.34951 48.88373, ...     62947.0   337.88
# 39  POLYGON ((2.32591 48.88853, 2.32575 48.88802, ...     29870.0   337.90
# 7   POLYGON ((2.34459 48.85405, 2.34459 48.85405, ...      9595.0   340.25
# 11  POLYGON ((2.30954 48.85396, 2.30646 48.85413, ...      7501.0   352.16
# 68  POLYGON ((2.36580 48.88554, 2.36469 48.88437, ...     67152.0   352.32
# 38  POLYGON ((2.29268 48.86044, 2.29195 48.85991, ...     23125.0   379.72
# 41  POLYGON ((2.34684 48.86491, 2.34668 48.86443, ...     32168.0   383.87
# 43  POLYGON ((2.36771 48.81742, 2.36696 48.81719, ...     36476.0   392.22
# 69  POLYGON ((2.34317 48.85139, 2.34268 48.85036, ...     64868.0   392.43
# 42  POLYGON ((2.35152 48.86443, 2.35095 48.86341, ...     47520.0   405.46
# 72  POLYGON ((2.34912 48.82960, 2.34954 48.82955, ...     53650.0   417.19
# 76  POLYGON ((2.33194 48.86491, 2.33135 48.86399, ...     35773.0   443.28
# 35  POLYGON ((2.32914 48.83413, 2.33153 48.83324, ...     22212.0   443.35
# 40  POLYGON ((2.37320 48.84057, 2.37241 48.84017, ...     33002.0   454.57
# 0   POLYGON ((2.31901 48.85174, 2.31903 48.85170, ...         NaN      NaN
#
# [80 rows x 11 columns]

# %%
b1=round(paris_plot.Pop_norm.max(),2)/4
b2=round(paris_plot.Population.max(),2)/2
b3=b1*3
b4=round(paris_plot.Population.max(),2)

# %% [markdown]
# >*Code for the paris map, with highlighting and a colorscale with legend*

# %%
bins = list(ppc['Dens_norm'].quantile([0,0.2,0.5,0.8,1]))

paris_map = folium.Map(location=[x_map, y_map], zoom_start=12)

tiles = ['stamenwatercolor', 'cartodbpositron', 'openstreetmap', 'stamenterrain']

for tile in tiles:
    folium.TileLayer(tile).add_to(paris_map)

choropleth = folium.Choropleth(      
    geo_data=geo_data,
    data=ppc,
    columns=['c_qu', 'Dens_norm'],
    key_on= 'feature.properties.c_qu',
    style_function = lambda colorscale: {
        'color': ppc.colorscale,
        'linecolor': 'black',
        'weight': 1,
        'fillOpacity': 0.1,
        'font-size': '10px',
        'font-weight': 'bold'
        },
    labels='l_qu',
    legend_name='Relative Population',
    bins=bins,
    highlight=True,
    reset=True
).add_to(paris_map)
    
folium.LayerControl().add_to(paris_map)

choropleth.geojson.add_child(
    folium.features.GeoJsonTooltip(
        fields=['l_qu', 'c_qu', 'c_ar', 'Population', 'perimetre'],
        aliases=['Name', 'Qtr #', 'Arr #', 'Population', 'Perimeter']
        ))                                                                                                   
paris_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# The map above shows each Quartier, shaded based on the colorscale created from the normalized density data. Total Population and the Perimeter distance is displayed when hovered over.  Darker areas convey more crowded quartiers, even though population may be higher in lighter areas which have more area.

# %%
CLIENT_ID = 'U4KD030Y4D1W4KHOW2TIKATHHUT4Z1NS2XR1T5FHYHTMCMPZ'
CLIENT_SECRET = 'AZUKDNM2EGIRD1PPR5DVQY114QXGWTAJUTN00Q5ABI0TBFF0' 
VERSION = '20180604'

LIMIT = 100

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
# Out:
# Your credentails:
# CLIENT_ID: U4KD030Y4D1W4KHOW2TIKATHHUT4Z1NS2XR1T5FHYHTMCMPZ

# %%
radius = 1000
LIMIT = 100

venues = []

for lat, long, neighborhood in zip(paris_plotting['Latitude'], paris_plotting['Longitude'], paris_plotting['Quartier']): 
    url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
        CLIENT_ID,
        CLIENT_SECRET,
        VERSION,
        lat,
        long,
        radius, 
        LIMIT)
    
    results = requests.get(url).json()['response']['groups'][0]['items']
    
    for venue in results:
        venues.append((
            neighborhood,
            lat, 
            long, 
            venue['venue']['name'], 
            venue['venue']['location']['lat'], 
            venue['venue']['location']['lng'],  
            venue['venue']['categories'][0]['name']))

# %%
venues_df = pd.DataFrame(venues)

venues_df.columns = ['Neighborhood', 'Latitude', 'Longitude', 'VenueName', 'VenueLatitude', 'VenueLongitude', 'VenueCategory']
df_na = venues_df['Neighborhood'] != 'Na'
venues_df = venues_df[df_na]
print(venues_df.shape)
venues_df.head()
# Out:
# (7801, 7)
#                 Neighborhood   Latitude  Longitude  \
# 0  Saint-Germain-l'Auxerrois  48.860211   2.336299
# 1  Saint-Germain-l'Auxerrois  48.860211   2.336299
# 2  Saint-Germain-l'Auxerrois  48.860211   2.336299
# 3  Saint-Germain-l'Auxerrois  48.860211   2.336299
# 4  Saint-Germain-l'Auxerrois  48.860211   2.336299
#
#                           VenueName  VenueLatitude  VenueLongitude  \
# 0                   Musée du Louvre      48.860847        2.336440
# 1             Cour Carrée du Louvre      48.860360        2.338543
# 2  La Vénus de Milo (Vénus de Milo)      48.859943        2.337234
# 3                     Pont des Arts      48.858565        2.337635
# 4                     Cour Napoléon      48.861172        2.335088
#
#       VenueCategory
# 0        Art Museum
# 1  Pedestrian Plaza
# 2           Exhibit
# 3            Bridge
# 4             Plaza

# %% [markdown]
# Tables below display data on Venue Category

# %%
venues_df.tail()
# Out:
#      Neighborhood   Latitude  Longitude            VenueName  VenueLatitude  \
# 7796     Charonne  48.854744   2.385356              Ragazzi      48.850873
# 7797     Charonne  48.854744   2.385356           Miss Lunch      48.850258
# 7798     Charonne  48.854744   2.385356     Café de la Danse      48.854095
# 7799     Charonne  48.854744   2.385356  Mademoiselle Jeanne      48.855926
# 7800     Charonne  48.854744   2.385356             Ethiopia      48.860833
#
#       VenueLongitude         VenueCategory
# 7796        2.392455    Italian Restaurant
# 7797        2.376652            Restaurant
# 7798        2.373044           Music Venue
# 7799        2.375477         Women's Store
# 7800        2.380000  Ethiopian Restaurant

# %%
venues_df.groupby(['Neighborhood']).mean().tail()
# Out:
#                   Latitude  Longitude  VenueLatitude  VenueLongitude
# Neighborhood
# Sorbonne         48.849123   2.345325      48.849413        2.345893
# Val-de-Grâce     48.842213   2.343882      48.843554        2.346202
# Vivienne         48.868859   2.339363      48.868356        2.339159
# École-Militaire  48.851848   2.304756      48.853709        2.304489
# Épinettes        48.893751   2.319856      48.889612        2.320360

# %% [markdown]
# Count of Venues in each Quartier

# %%
venues_df.groupby(['Neighborhood', 'VenueCategory']).count()
# Out:
#                                             Latitude  Longitude  VenueName  \
# Neighborhood VenueCategory
# Amérique     Art Gallery                           1          1          1
#              Art Museum                            1          1          1
#              Arts & Entertainment                  1          1          1
#              Asian Restaurant                      1          1          1
#              Bakery                                4          4          4
#              Bar                                   6          6          6
#              Bed & Breakfast                       1          1          1
#              Beer Garden                           1          1          1
#              Bistro                                1          1          1
#              Burger Joint                          1          1          1
#              Bus Stop                              1          1          1
#              Café                                  1          1          1
#              Chinese Restaurant                    1          1          1
#              Concert Hall                          2          2          2
#              Dessert Shop                          1          1          1
#              French Restaurant                    14         14         14
#              Gastropub                             1          1          1
#              Gourmet Shop                          1          1          1
#              Grocery Store                         2          2          2
#              Historic Site                         1          1          1
#              Hotel                                 5          5          5
#              Indian Restaurant                     1          1          1
#              Indoor Play Area                      1          1          1
#              Italian Restaurant                    3          3          3
#              Japanese Restaurant                   4          4          4
#              Market                                1          1          1
#              Metro Station                         2          2          2
#              Moroccan Restaurant                   1          1          1
#              Museum                                1          1          1
#              Music Store                           1          1          1
# ...                                              ...        ...        ...
# Épinettes    Doner Restaurant                      1          1          1
#              Ethiopian Restaurant                  1          1          1
#              Farmers Market                        1          1          1
#              Fast Food Restaurant                  1          1          1
#              French Restaurant                    20         20         20
#              Garden                                1          1          1
#              Gastropub                             1          1          1
#              Gym / Fitness Center                  2          2          2
#              Health Food Store                     1          1          1
#              Hotel                                 4          4          4
#              Indian Restaurant                     2          2          2
#              Italian Restaurant                    3          3          3
#              Japanese Restaurant                   3          3          3
#              Latin American Restaurant             1          1          1
#              Lounge                                1          1          1
#              Park                                  3          3          3
#              Pastry Shop                           1          1          1
#              Pedestrian Plaza                      1          1          1
#              Pizza Place                           6          6          6
#              Plaza                                 2          2          2
#              Portuguese Restaurant                 1          1          1
#              Restaurant                            6          6          6
#              Seafood Restaurant                    1          1          1
#              Supermarket                           1          1          1
#              Sushi Restaurant                      2          2          2
#              Thai Restaurant                       2          2          2
#              Theater                               1          1          1
#              Turkish Restaurant                    2          2          2
#              Vegetarian / Vegan Restaurant         1          1          1
#              Wine Bar                              2          2          2
#
#                                             VenueLatitude  VenueLongitude
# Neighborhood VenueCategory
# Amérique     Art Gallery                                1               1
#              Art Museum                                 1               1
#              Arts & Entertainment                       1               1
#              Asian Restaurant                           1               1
#              Bakery                                     4               4
#              Bar                                        6               6
#              Bed & Breakfast                            1               1
#              Beer Garden                                1               1
#              Bistro                                     1               1
#              Burger Joint                               1               1
#              Bus Stop                                   1               1
#              Café                                       1               1
#              Chinese Restaurant                         1               1
#              Concert Hall                               2               2
#              Dessert Shop                               1               1
#              French Restaurant                         14              14
#              Gastropub                                  1               1
#              Gourmet Shop                               1               1
#              Grocery Store                              2               2
#              Historic Site                              1               1
#              Hotel                                      5               5
#              Indian Restaurant                          1               1
#              Indoor Play Area                           1               1
#              Italian Restaurant                         3               3
#              Japanese Restaurant                        4               4
#              Market                                     1               1
#              Metro Station                              2               2
#              Moroccan Restaurant                        1               1
#              Museum                                     1               1
#              Music Store                                1               1
# ...                                                   ...             ...
# Épinettes    Doner Restaurant                           1               1
#              Ethiopian Restaurant                       1               1
#              Farmers Market                             1               1
#              Fast Food Restaurant                       1               1
#              French Restaurant                         20              20
#              Garden                                     1               1
#              Gastropub                                  1               1
#              Gym / Fitness Center                       2               2
#              Health Food Store                          1               1
#              Hotel                                      4               4
#              Indian Restaurant                          2               2
#              Italian Restaurant                         3               3
#              Japanese Restaurant                        3               3
#              Latin American Restaurant                  1               1
#              Lounge                                     1               1
#              Park                                       3               3
#              Pastry Shop                                1               1
#              Pedestrian Plaza                           1               1
#              Pizza Place                                6               6
#              Plaza                                      2               2
#              Portuguese Restaurant                      1               1
#              Restaurant                                 6               6
#              Seafood Restaurant                         1               1
#              Supermarket                                1               1
#              Sushi Restaurant                           2               2
#              Thai Restaurant                            2               2
#              Theater                                    1               1
#              Turkish Restaurant                         2               2
#              Vegetarian / Vegan Restaurant              1               1
#              Wine Bar                                   2               2
#
# [3983 rows x 5 columns]

# %%
print('There are {} unique categories.'.format(len(venues_df['VenueCategory'].unique())))
# Out:
# There are 295 unique categories.

# %%
#venues_df['VenueCategory'].unique()[:]

# %%
venues_df['Population'] = paris_plotting['Population']
venues_df
# Out:
#                    Neighborhood   Latitude  Longitude  \
# 0     Saint-Germain-l'Auxerrois  48.860211   2.336299
# 1     Saint-Germain-l'Auxerrois  48.860211   2.336299
# 2     Saint-Germain-l'Auxerrois  48.860211   2.336299
# 3     Saint-Germain-l'Auxerrois  48.860211   2.336299
# 4     Saint-Germain-l'Auxerrois  48.860211   2.336299
# 5     Saint-Germain-l'Auxerrois  48.860211   2.336299
# 6     Saint-Germain-l'Auxerrois  48.860211   2.336299
# 7     Saint-Germain-l'Auxerrois  48.860211   2.336299
# 8     Saint-Germain-l'Auxerrois  48.860211   2.336299
# 9     Saint-Germain-l'Auxerrois  48.860211   2.336299
# 10    Saint-Germain-l'Auxerrois  48.860211   2.336299
# 11    Saint-Germain-l'Auxerrois  48.860211   2.336299
# 12    Saint-Germain-l'Auxerrois  48.860211   2.336299
# 13    Saint-Germain-l'Auxerrois  48.860211   2.336299
# 14    Saint-Germain-l'Auxerrois  48.860211   2.336299
# 15    Saint-Germain-l'Auxerrois  48.860211   2.336299
# 16    Saint-Germain-l'Auxerrois  48.860211   2.336299
# 17    Saint-Germain-l'Auxerrois  48.860211   2.336299
# 18    Saint-Germain-l'Auxerrois  48.860211   2.336299
# 19    Saint-Germain-l'Auxerrois  48.860211   2.336299
# 20    Saint-Germain-l'Auxerrois  48.860211   2.336299
# 21    Saint-Germain-l'Auxerrois  48.860211   2.336299
# 22    Saint-Germain-l'Auxerrois  48.860211   2.336299
# 23    Saint-Germain-l'Auxerrois  48.860211   2.336299
# 24    Saint-Germain-l'Auxerrois  48.860211   2.336299
# 25    Saint-Germain-l'Auxerrois  48.860211   2.336299
# 26    Saint-Germain-l'Auxerrois  48.860211   2.336299
# 27    Saint-Germain-l'Auxerrois  48.860211   2.336299
# 28    Saint-Germain-l'Auxerrois  48.860211   2.336299
# 29    Saint-Germain-l'Auxerrois  48.860211   2.336299
# ...                         ...        ...        ...
# 7771                   Charonne  48.854744   2.385356
# 7772                   Charonne  48.854744   2.385356
# 7773                   Charonne  48.854744   2.385356
# 7774                   Charonne  48.854744   2.385356
# 7775                   Charonne  48.854744   2.385356
# 7776                   Charonne  48.854744   2.385356
# 7777                   Charonne  48.854744   2.385356
# 7778                   Charonne  48.854744   2.385356
# 7779                   Charonne  48.854744   2.385356
# 7780                   Charonne  48.854744   2.385356
# 7781                   Charonne  48.854744   2.385356
# 7782                   Charonne  48.854744   2.385356
# 7783                   Charonne  48.854744   2.385356
# 7784                   Charonne  48.854744   2.385356
# 7785                   Charonne  48.854744   2.385356
# 7786                   Charonne  48.854744   2.385356
# 7787                   Charonne  48.854744   2.385356
# 7788                   Charonne  48.854744   2.385356
# 7789                   Charonne  48.854744   2.385356
# 7790                   Charonne  48.854744   2.385356
# 7791                   Charonne  48.854744   2.385356
# 7792                   Charonne  48.854744   2.385356
# 7793                   Charonne  48.854744   2.385356
# 7794                   Charonne  48.854744   2.385356
# 7795                   Charonne  48.854744   2.385356
# 7796                   Charonne  48.854744   2.385356
# 7797                   Charonne  48.854744   2.385356
# 7798                   Charonne  48.854744   2.385356
# 7799                   Charonne  48.854744   2.385356
# 7800                   Charonne  48.854744   2.385356
#
#                                               VenueName  VenueLatitude  \
# 0                                       Musée du Louvre      48.860847
# 1                                 Cour Carrée du Louvre      48.860360
# 2                      La Vénus de Milo (Vénus de Milo)      48.859943
# 3                                         Pont des Arts      48.858565
# 4                                         Cour Napoléon      48.861172
# 5                    Vestige de la Forteresse du Louvre      48.861577
# 6                                 Place du Palais Royal      48.862523
# 7                                       Place du Louvre      48.859841
# 8                                          Palais Royal      48.863236
# 9                                     Comédie-Française      48.863088
# 10    Pavillon des Sessions – Arts d'Afrique, d'Asie...      48.860724
# 11                                            Buly 1803      48.857146
# 12                                        Place Colette      48.863145
# 26          2.342380    Chinese Restaurant     12895.0
# 27          2.332224                 Plaza     25156.0
# 28          2.333751        Cosmetics Shop      4614.0
# 29          2.339756                   Spa     10038.0
# ...              ...                   ...         ...
# 7771        2.374268    Italian Restaurant         NaN
# 7772        2.376807                Bakery         NaN
# 7773        2.375296             Bookstore         NaN
# 7774        2.374729     French Restaurant         NaN
# 7775        2.378006     French Restaurant         NaN
# 7776        2.374692      Asian Restaurant         NaN
# 7777        2.375970        Clothing Store         NaN
# 7778        2.375506                   Bar         NaN
# 7779        2.396344          Tech Startup         NaN
# 7780        2.390695             Gastropub         NaN
# 7781        2.378083        Farmers Market         NaN
# 7782        2.380911            Art Museum         NaN
# 7783        2.382223    Italian Restaurant         NaN
# 7784        2.374225                   Bar         NaN
# 7785        2.375356           Art Gallery         NaN
# 7786        2.378143          Cocktail Bar         NaN
# 7787        2.379967                Bakery         NaN
# 7788        2.377445              Wine Bar         NaN
# 7789        2.374424                Bistro         NaN
# 7790        2.374693                   Pub         NaN
# 7791        2.375562           Record Shop         NaN
# 7792        2.378424            Restaurant         NaN
# 7793        2.380342                 Plaza         NaN
# 7794        2.383766  Gym / Fitness Center         NaN
# 7795        2.375098           Record Shop         NaN
# 7796        2.392455    Italian Restaurant         NaN
# 7797        2.376652            Restaurant         NaN
# 7798        2.373044           Music Venue         NaN
# 7799        2.375477         Women's Store         NaN
# 7800        2.380000  Ethiopian Restaurant         NaN
#
# [7801 rows x 8 columns]

# %%
label_list = {'Neighborhood', 'Latitude', 'Longitude', 'Population', 'VenueName', 'VenueLatitude', 'VenueLongitude', 'VenueCategory'}
label_list = pd.DataFrame(label_list)
paris_hot = venues_df.groupby(venues_df['VenueCategory']).sum()
#parislist = parislist.reset_index(label_list)
print(paris_hot.shape)
paris_hot[1:100]
# Out:
# (295, 5)
#                               Latitude   Longitude  VenueLatitude  \
# VenueCategory
# Afghan Restaurant            97.718331    4.756002      97.724653
# African Restaurant          977.489479   47.228610     977.499224
# Alsatian Restaurant         293.157295   14.116191     293.149650
# American Restaurant         781.931240   37.466109     781.924194
# Arepa Restaurant             97.786184    4.679202      97.781968
# Argentinian Restaurant      488.680061   23.336139     488.671213
# Art Gallery                2834.038378  136.280517    2834.028182
# Art Museum                 3322.538343  158.585048    3322.517366
# Arts & Crafts Store         244.202696   11.813672     244.200374
# Arts & Entertainment         48.882424    2.394025      48.879041
# Asian Restaurant           3175.441342  153.300106    3175.414566
# Athletics & Sports          244.297565   11.717965     244.317192
# Auvergne Restaurant         293.060282   13.940088     293.043431
# BBQ Joint                   635.342197   30.633572     635.341237
# Baby Store                   97.673691    4.577266      97.671981
# Bagel Shop                  488.735965   23.392964     488.725804
# Bakery                    11188.975537  535.547416   11188.971343
# Bank                         48.821991    2.337792      48.825700
# Bar                       11630.675997  561.483638   11630.532625
# Basketball Court             97.758565    4.682462      97.764237
# Basque Restaurant           537.364555   25.479006     537.362682
# Beach Bar                    97.711284    4.589921      97.715819
# Bed & Breakfast             293.267390   14.182392     293.268465
# Beer Bar                   2247.934809  108.565371    2247.885659
# Beer Garden                 830.429874   39.881749     830.446552
# Cosmetics Shop                 65.510132     12115.0
# Creperie                      168.815912         0.0
# Cultural Center                25.847519         0.0
# Cupcake Shop                   18.712800         0.0
# Cycle Studio                   16.428698         0.0
# Dance Studio                   26.021454         0.0
# Deli / Bodega                  42.301190         0.0
# Department Store               74.533674         0.0
# Design Studio                   4.698637         0.0
# Dessert Shop                  114.420806         0.0
# Dim Sum Restaurant             18.977172         0.0
# Diner                          51.916779         0.0
# Discount Store                  2.327726         0.0
# Dive Bar                        2.335715         0.0
# Doner Restaurant               14.112291         0.0
# Donut Shop                     18.778726         0.0
# Drive-in Theater                4.784095         0.0
# Electronics Store              37.296987         0.0
# English Restaurant             11.677430         0.0
# Escape Room                    14.068180         0.0
# Ethiopian Restaurant           35.299593         0.0
# Event Space                     4.781241         0.0
# Exhibit                        23.336223     68506.0
# Falafel Restaurant             44.961047         0.0
# Farmers Market                 98.628871         0.0
# Fast Food Restaurant           30.705807         0.0
# Film Studio                     4.552145         0.0
#
# [99 rows x 5 columns]

# %% [markdown]
# >*Find the number of Cafes and Creperies and compare to the population density of each*

# %%
len(paris_hot.index['Creperie'] > 0)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-584-88c887b592e5> in <module>()
# ----> 1 len(paris_hot.index['Creperie'] > 0)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    3956         if is_scalar(key):
#    3957             key = com.cast_scalar_indexer(key)
# -> 3958             return getitem(key)
#    3959
#    3960         if isinstance(key, slice):
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
len(parislist[parislist['Coffee Shop'] > 0])

# %%
len(paris_hot[paris_hot['Chinese Restaurant'] > 0])

# %%
paris_crepes = paris_hot[['Quartier','Creperie','Coffee Shop', 'Chinese Restaurant']]

# %%
paris_crepes_group = paris_crepes.groupby(['Quartier']).sum().reset_index()
paris_crepes_group.head()

# %% [markdown]
# # **Results**
# >*From the data we can extract and compare the availabilty of various establishments.  Paris has a wide variety of establishments, usually clustering in specific neighborhoods.  In addition, Each neighboorhood seems to have a least one of each establishment*

# %%
par_d = pd.DataFrame(paris_hot_grouped, columns = ['Quartier', 'Creperies', 'Cafes', 'Chinese', 'Density (pop per hectare)'])
par_d['Quartier'] = parcoord['Quartier']
par_d['Creperies'] = paris_crepes_group['Creperie']
par_d['Cafes'] = paris_crepes_group['Coffee Shop']
par_d['Chinese'] = paris_crepes_group['Chinese Restaurant']
par_d['Density (pop per hectare)'] = parcoord['Density'].astype(int)
par_d

# %%
paris_hot = pd.get_dummies(venues_df[['VenueCategory']], prefix="", prefix_sep="")

paris_hot['Quartier'] = venues_df['Quartier'] 

fixed_columns = [paris_hot.columns[-1]] + list(paris_hot.columns[:-1])
paris_hot = paris_hot[fixed_columns]

print(paris_hot.shape)

paris_hot.head()

# %%
lower_left = [latlow, lonlow]
upper_right = [lathigh, lonhigh]
grid = get_geojson_grid(upper_right, lower_left , n=8)

for i, geo_json in enumerate(grid):

    color = plt.cm.Reds(i / len(grid))
    color = mpl.colors.to_hex(color)

    gj = folium.GeoJson(geo_json,
                        style_function=lambda feature, color=color: {
                            'fillColor': color,
                            'color':"black",
                            'weight': 2,
                            'dashArray': '5, 5',
                            'fillOpacity': 0.35,
                        })
    popup = folium.Popup("Quartier {}".format(i))
    gj.add_child(popup)

    
    m.add_child(gj)
m

# %%
latlow = min(df_.location_latitude) + .0025
lonlow = min(df_.location_longitude)  + .0025
lathigh = max(df_.location_latitude) + .0025
lonhigh = max(df_.location_longitude) + .0025

m = folium.Map(zoom_start = 5, location=[48.8, 2.30])

top_right = [lathigh, lonlow]
top_left = [latlow, lonhigh]

grid = get_geojson_grid(top_right, top_left, n=6)

popups = []
regional_counts = []

for box in grid:
    upper_right = box["properties"]["upper_right"]
    lower_left = box["properties"]["lower_left"]

    mask = (
        (lonhigh = upper_right[1]) & (latlow = lower_left[1]) &
        (lathigh = upper_right[0]) & (lonlow = lower_left[0])
           )

    region_density = len(df_[mask])
    regional_counts.append(region_density)

    total_pop = parcoord[mask].Population.sum()
    total_density = parcoord[mask].Density.sum()
    content = "total population {:,.0f}, total density {:,.0f}".format(total_pop, total_density)
    popup = folium.Popup(content)
    popups.append(popup)

worst_region = max(regional_counts)

for i, box in enumerate(grid):
    geo_json = json.dumps(box)

    color = plt.cm.Reds(regional_counts[i] / worst_region)
    color = mpl.colors.to_hex(color)

    gj = folium.GeoJson(geo_json,
                        style_function=lambda feature, color=color: {
                                                                        'fillColor': color,
                                                                        'color':"black",
                                                                        'weight': 2,
                                                                        'dashArray': '5, 5',
                                                                        'fillOpacity': 0.35,
                                                                    })

    gj.add_child(popups[i])
    m.add_child(gj)

locations = list(zip(df_.location_latitude, df_.location_longitude))
icons = [folium.Icon(icon="star", prefix="fa") for _ in range(len(locations))]

popup_content = []
for incident in pop_data.itertuples():
    Population = "Population: {} ".format(incident.Population)
    Density = "Density: {}".format(incident.Density)
    content = number_of_vehicles + number_of_casualties
    popup_content.append(content)

popups = [folium.Popup(content) for content in popup_content]

cluster = MarkerCluster(locations=locations, icons=icons, popups=popups)
m.add_child(cluster)

m.save("pop_paris.html")

# %% [markdown]
# *Create and push data into a new csv file*

# %%
location = pd.DataFrame() 
#location[1] = parcoord['Latitude'].values.tolist()
#location[0] = parcoord['Longitude'].values.tolist()
#location[1]

# %%
location.values[0:80]
location

# %%
paris_map = gpd.read_file('arrondissements.shp')
print(paris_map)

# %%
gdf.plot(ax=ax, color='orange')

plt.show()

# %%
df_.head()

# %% [markdown]
# *Create a Pandas DataFrame with the listed column headers as a more concise version*

# %%
label = []

p_map = folium.Map(zoom_start=12)

for row in df_.iterrows():
    folium.CircleMarker(
    #label = '{}'.format(name),
    label = folium.Popup(label, parse_html=True),
    location = [df_.location_latittude.values, df_.location_longitude.values],
    radius=5,
    popup=label,
    color='blue',
    fill=True,
    fill_color='#3186cc')

add(p_map)

p_map

# %%
venues_df = pd.DataFrame(venues)

venues_df.columns = ['Arrondissement', 'Latitude', 'Longitude', 'VenueName', 'VenueLatitude', 'VenueLongitude', 'VenueCategory']
venues_df['Density'] = arronds['Density']
df_na = venues_df['Arrondissement'] != 'Na'
df_bar = venues_df['VenueCategory'] != 'Bar'
count_df = count(venues_df['VenueCategory'] / count(venue_df)
venues_df.count(['VenueCategory'])
venue['VenueConcentration'] = count[i]
venues_df = venues_df[df_na]
print(venues_df.shape)
venues_df.head()
venues_df.tail()

# %%
grouped_cat = venues_df. groupby(["VenueCategory", "Density"])
for key,item in grouped_cat:
    cat_group = grouped_cat.get_group(key)
print(cat_group, "\n")
